# %% [markdown]
# # Lab 5: MNIST CNN Classifier
#
# **COMP 395 — Deep Learning**
# **Due: March 20, 2026**
# **Individual assignment**
#
# ---
#
# ## Overview
#
# In this lab you will train convolutional neural networks to classify handwritten digits from the MNIST dataset. You will start by training an MLP baseline, then build and train the `SimpleCNN` from our in-class lab, and finally experiment with architectural modifications — all tracked with MLflow.
#
# This lab is intentionally less scaffolded than previous labs. You have done every individual piece before (data loading, training loops, evaluation, MLflow logging). The challenge here is putting them together independently in a new context.

# %% [markdown]
# ## Setup
#
# You will need the following libraries. Refer to your earlier labs if you don't remember how any of these work.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import mlflow
import mlflow.pytorch
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Part 1: Data Loading and Preprocessing
#
# We load the MNIST dataset using `torchvision`. The key steps:
#
# - `transforms.ToTensor()` converts PIL images to PyTorch tensors and scales pixel values from [0, 255] to [0, 1]. It also rearranges the shape to `(C, H, W)` — the format `nn.Conv2d` expects.
# - `transforms.Normalize((0.1307,), (0.3081,))` standardizes using the MNIST dataset's global mean and standard deviation. This centers the data around zero, which helps training converge faster.
# - We create separate `DataLoader`s for training and testing. The training loader shuffles; the test loader does not (shuffling the test set would change nothing about evaluation, but ordered data is easier to inspect).

# %%
# Preprocessing pipeline
transform = transforms.Compose([
    transforms.ToTensor(),                        # PIL -> tensor, scales to [0, 1], shape (1, 28, 28)
    transforms.Normalize((0.1307,), (0.3081,)),   # standardize with MNIST mean/std
])

# Download and load MNIST
train_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, download=True, transform=transform
)
test_dataset = torchvision.datasets.MNIST(
    root='./data', train=False, download=True, transform=transform
)

# Create DataLoaders
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Training samples: {len(train_dataset)}")
print(f"Test samples:     {len(test_dataset)}")
print(f"Batch size:       {batch_size}")
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# Training samples: 60000
# Test samples:     10000
# Batch size:       64

# %% [markdown]
# ### 1.1 Understanding the DataLoader
#
# Before you start training, take a moment to understand what the `DataLoader` is actually giving you. A `DataLoader` wraps a dataset and provides:
#
# - **Batching:** instead of feeding one image at a time, it groups images into batches (e.g., 64 at once). This is more efficient for the GPU and provides a more stable gradient estimate.
# - **Shuffling:** randomizes the order each epoch so the model doesn't memorize the sequence.
# - **An iterator:** you loop over it with `for images, labels in dataloader:` and it yields one batch at a time.
#
# Run the cell below to inspect what comes out of the DataLoader.

# %%
# Grab one batch from the training DataLoader
images, labels = next(iter(train_loader))

print(f"Batch of images shape: {images.shape}")
print(f"Batch of labels shape: {labels.shape}")
print(f"Label dtype: {labels.dtype}")
print()

# Unpack the shape
N, C, H, W = images.shape
print(f"  N = {N}  (batch size — number of images in this batch)")
print(f"  C = {C}  (channels — 1 for grayscale, 3 for RGB)")
print(f"  H = {H}  (height in pixels)")
print(f"  W = {W}  (width in pixels)")
print()

# Pixel value range after your transforms
print(f"Pixel value range: [{images.min():.4f}, {images.max():.4f}]")
print(f"  (If you normalized with mean=0.1307, std=0.3081,")
print(f"   these won't be [0,1] anymore — that's expected.)")
print()

# What does one label look like?
print(f"First 10 labels in this batch: {labels[:10].tolist()}")
print(f"  (These are integers 0-9, one per image.)")
# Out:
# Batch of images shape: torch.Size([64, 1, 28, 28])
# Batch of labels shape: torch.Size([64])
# Label dtype: torch.int64
#
#   N = 64  (batch size — number of images in this batch)
#   C = 1  (channels — 1 for grayscale, 3 for RGB)
#   H = 28  (height in pixels)
#   W = 28  (width in pixels)
#
# Pixel value range: [-0.4242, 2.8215]
#   (If you normalized with mean=0.1307, std=0.3081,
#    these won't be [0,1] anymore — that's expected.)
#
# First 10 labels in this batch: [1, 7, 0, 0, 5, 1, 3, 4, 0, 4]
#   (These are integers 0-9, one per image.)

# %%
# Visualize a few images from the batch to confirm everything looks right
fig, axes = plt.subplots(1, 8, figsize=(14, 2))
for i in range(8):
    # images[i] has shape (C, H, W) — squeeze out the channel dim for grayscale
    img = images[i].squeeze().numpy()
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Label: {labels[i].item()}", fontsize=11)
    axes[i].axis('off')
plt.suptitle("Sample batch from DataLoader", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 How the DataLoader fits into training
#
# When you write a training loop, the DataLoader is what you iterate over:
#
# ```python
# for epoch in range(num_epochs):
#     for images, labels in train_loader:   # <-- one batch at a time
#         outputs = model(images)            # forward pass on the batch
#         loss = criterion(outputs, labels)  # compute loss for the batch
#         ...
# ```
#
# Each call to the loop yields a fresh batch. After you've gone through every batch once, that's one **epoch**. The DataLoader handles all the bookkeeping of which samples have been used, reshuffling, etc.
#
# **Checkpoint:** Before moving on, make sure you can answer:
#
# 1. What is the shape of a single batch of images from your DataLoader?
# torch.Size([64,1,28,28])
# 2. What do the labels look like — are they integers or one-hot vectors?
# Integers
# 3. How many batches are in one epoch? (Hint: `len(train_loader)`)
# 938
#
# ---

# %%
# How many batches per epoch?
print(f"Training batches per epoch: {len(train_loader)}")
print(f"  = {len(train_loader.dataset)} images / {train_loader.batch_size} per batch")
# Out:
# Training batches per epoch: 938
#   = 60000 images / 64 per batch

# %% [markdown]
# ## Part 2: MLP Baseline
#
# Before building a CNN, we train a simple MLP on MNIST as a baseline. This gives you a point of comparison and — just as importantly — establishes the training loop and evaluation code that you'll reuse for every experiment that follows.
#
# Study this section carefully. For Parts 3–5, you'll swap in a different model but keep everything else.

# %% [markdown]
# ### 2.1 Model Definition
#
# The MLP flattens each 28×28 image into a 784-dimensional vector and passes it through fully connected layers. This throws away all spatial structure — the model has no idea that pixel (0,0) is next to pixel (0,1). That's exactly the limitation CNNs will fix.

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()              # (N, 1, 28, 28) -> (N, 784)
        self.fc1 = nn.Linear(28 * 28, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)                         # raw logits — no softmax here
        return x

mlp_model = MLP()

# Count parameters
total_params = sum(p.numel() for p in mlp_model.parameters())
print(f"MLP parameters: {total_params:,}")
print(f"  fc1: 784 × 256 + 256 = {784*256 + 256:,}")
print(f"  fc2: 256 × 128 + 128 = {256*128 + 128:,}")
print(f"  fc3: 128 × 10  + 10  = {128*10 + 10:,}")
# Out:
# MLP parameters: 235,146
#   fc1: 784 × 256 + 256 = 200,960
#   fc2: 256 × 128 + 128 = 32,896
#   fc3: 128 × 10  + 10  = 1,290

# %% [markdown]
# ### 2.2 Training Loop
#
# This is the same train loop pattern from Lab 4. We use cross-entropy loss (which expects raw logits, not softmax outputs) and Adam optimizer.
#
# We also define an `evaluate` function that we'll reuse for every experiment.

# %%
def evaluate(model, data_loader):
    """Compute accuracy and collect all predictions for a model on a DataLoader."""
    model.eval()
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in data_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    return accuracy, np.array(all_preds), np.array(all_labels)

# %%
# Training setup
num_epochs = 10
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(mlp_model.parameters(), lr=learning_rate)

# Training loop
mlp_loss_history = []

for epoch in range(num_epochs):
    mlp_model.train()
    running_loss = 0.0

    for images, labels in train_loader:
        # Forward pass
        outputs = mlp_model(images)
        loss = criterion(outputs, labels)

        # Backward pass and update
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    mlp_loss_history.append(avg_loss)

    # Check accuracy every few epochs
    if (epoch + 1) % 2 == 0 or epoch == 0:
        acc, _, _ = evaluate(mlp_model, test_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}]  Loss: {avg_loss:.4f}  Test Acc: {acc:.4f}")
# Out:
# Epoch [1/10]  Loss: 0.2281  Test Acc: 0.9639
# Epoch [2/10]  Loss: 0.0932  Test Acc: 0.9668
# Epoch [4/10]  Loss: 0.0510  Test Acc: 0.9771
# Epoch [6/10]  Loss: 0.0330  Test Acc: 0.9790
# Epoch [8/10]  Loss: 0.0253  Test Acc: 0.9746
# Epoch [10/10]  Loss: 0.0220  Test Acc: 0.9775

# %% [markdown]
# ### 2.3 Evaluation

# %%
# Final evaluation
mlp_accuracy, mlp_preds, mlp_labels = evaluate(mlp_model, test_loader)
print(f"MLP final test accuracy: {mlp_accuracy:.4f}")

#added after
mlp_test_acc, _, _ = evaluate(mlp_model, test_loader)

# Plot training loss
plt.figure(figsize=(8, 4))
plt.plot(range(1, num_epochs + 1), mlp_loss_history, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("MLP Baseline — Training Loss")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# MLP final test accuracy: 0.9775

# %%
# Confusion matrix
cm = confusion_matrix(mlp_labels, mlp_preds)
fig, ax = plt.subplots(figsize=(8, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(10)))
disp.plot(ax=ax, cmap='Blues', values_format='d')
ax.set_title("MLP Baseline — Confusion Matrix")
plt.tight_layout()
plt.show()

# Save for MLflow logging later
fig.savefig("mlp_confusion_matrix.png", dpi=100, bbox_inches='tight')
print("Saved mlp_confusion_matrix.png")
# Out:
# Saved mlp_confusion_matrix.png

# %% [markdown]
# ### 2.4 MLflow Logging (Optional — Do This Now or in Part 6)
#
# The cell below logs everything for this run. You can run it now or come back during Part 6. Either way, you'll need to do this for every experiment, so it's worth getting it working here first.

# %%
#Uncomment and run when you're ready to log to MLflow
#(Make sure your MLflow tracking server/URI is configured from earlier labs)

mlflow.set_experiment("Lab5-MNIST")

with mlflow.start_run(run_name="MLP-baseline"):
    # Parameters
    mlflow.log_param("model_type", "MLP")
    mlflow.log_param("learning_rate", learning_rate)
    mlflow.log_param("batch_size", batch_size)
    mlflow.log_param("num_epochs", num_epochs)
    mlflow.log_param("optimizer", "Adam")

    # Tag
    mlflow.set_tag("architecture", "MLP-784-256-128-10")

    # Metrics — log loss for each epoch
    for epoch, loss_val in enumerate(mlp_loss_history):
        mlflow.log_metric("train_loss", loss_val, step=epoch + 1)
    mlflow.log_metric("test_accuracy", mlp_accuracy)

    # Artifact — confusion matrix
    mlflow.log_artifact("mlp_confusion_matrix.png")

    print(f"Logged MLP baseline: accuracy={mlp_accuracy:.4f}")
# Out:
# 2026/03/21 16:02:02 INFO mlflow.tracking.fluent: Experiment with name 'Lab5-MNIST' does not exist. Creating a new experiment.
# Logged MLP baseline: accuracy=0.9775

# %% [markdown]
# ---
#
# ### What to reuse for Parts 3–5
#
# When you build your CNN and run experiments, you should reuse:
#
# - **`evaluate()`** — works with any model, no changes needed.
# - **The training loop** — the only thing that changes is which model and optimizer you pass in. Consider wrapping it in a function:
#
# ```python
# def train_model(model, train_loader, num_epochs=10, lr=0.001):
#     criterion = nn.CrossEntropyLoss()
#     optimizer = optim.Adam(model.parameters(), lr=lr)
#     loss_history = []
#     for epoch in range(num_epochs):
#         model.train()
#         running_loss = 0.0
#         for images, labels in train_loader:
#             optimizer.zero_grad()
#             outputs = model(images)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()
#             running_loss += loss.item()
#         loss_history.append(running_loss / len(train_loader))
#     return loss_history
# ```
#
# - **The confusion matrix code** — just change the filename and title.
# - **The MLflow logging pattern** — change the run name, tag, and parameters.
#
# ---

# %% [markdown]
# ## Part 3: CNN Classifier
#
# Now build and train a CNN on the same data. You can use the `SimpleCNN` from the Day 2 in-class lab, or write your own architecture.
#
# **Requirements:**
#
# - At least two convolutional layers with ReLU and max pooling.
# - A fully connected classification head that outputs 10 classes.
# - Train using cross-entropy loss and an appropriate optimizer.
# - Log the run to MLflow.
# - Record the final test accuracy and compare to your MLP baseline.
#
# The only thing that changes from Part 2 is the model definition. Your data loading, training loop, and evaluation code should be reusable. If they aren't, refactor them into a function.

# %%
# Define your CNN model
import torch
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))   # 28 → 14
        x = self.pool(F.relu(self.conv2(x)))   # 14 → 7
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
# Train the CNN and log to MLflow

import mlflow
import mlflow.pytorch

model = SimpleCNN()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

with mlflow.start_run():
    mlflow.log_param("model", "SimpleCNN")
    mlflow.log_param("lr", 0.001)
    mlflow.log_param("epochs", 5)

    cnn_losses = []
    cnn_accs = []

    for epoch in range(5):
        model.train()
        running_loss = 0.0

        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        cnn_losses.append(avg_loss)

        acc, _, _ = evaluate(model, test_loader)
        cnn_accs.append(acc)

        mlflow.log_metric("loss", avg_loss, step=epoch)
        mlflow.log_metric("accuracy", acc, step=epoch)

        print(f"Epoch {epoch+1}: Loss={avg_loss:.4f}, Acc={acc:.4f}")

    mlflow.log_metric("final_accuracy", cnn_accs[-1])
    mlflow.pytorch.log_model(model, "cnn_model")
# Out:
# Epoch 1: Loss=0.1663, Acc=0.9837
# Epoch 2: Loss=0.0508, Acc=0.9876
# Epoch 3: Loss=0.0360, Acc=0.9872
# Epoch 4: Loss=0.0269, Acc=0.9879
# 2026/03/21 16:03:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/21 16:03:47 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 5: Loss=0.0209, Acc=0.9899

# %%
# Evaluate on the test set and print accuracy
# Compare to your MLP baseline

cnn_test_acc, _, _ = evaluate(model, test_loader)

print(f"CNN Test Accuracy: {cnn_test_acc:.4f}")

# replace with your actual MLP accuracy variable if different
print(f"MLP Test Accuracy: {mlp_test_acc:.4f}")

if cnn_test_acc > mlp_test_acc:
    print("CNN outperforms MLP")
else:
    print("MLP outperforms CNN")
# Out:
# CNN Test Accuracy: 0.9899
# MLP Test Accuracy: 0.9775
# CNN outperforms MLP

# %% [markdown]
# ## Part 4: Required Experiments — Kernel Size and Filter Counts
#
# Modify the CNN architecture in at least **two** of the following ways. Each should be a separate MLflow run with a descriptive tag so you can compare them later.
#
# **Choose at least two:**
#
# - Change the convolutional kernel size (e.g., from 3×3 to 5×5).
# - Change the number of filters (e.g., from 16→32 to 32→64, or reduce to 8→16).
# - Try both changes together.
#
# **Important:** if you change the kernel size or the number of pooling layers, the spatial dimensions at the flatten step will change. You need to recompute the input size for your first fully connected layer. Use the shape-tracing technique from the Day 2 lab.
#
# For each experiment, record: what you changed, what you expected to happen, and what actually happened.

# %%
# Experiment 1 - more filters
class CNN_MoreFilters(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# Train CNN, log to MLflow
model_exp1 = CNN_MoreFilters()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_exp1.parameters(), lr=0.001)

with mlflow.start_run():
    mlflow.log_param("model", "CNN_MoreFilters")
    mlflow.log_param("lr", 0.001)
    mlflow.log_param("epochs", 5)

    exp1_losses = []
    exp1_accs = []

    for epoch in range(5):
        model_exp1.train()
        running_loss = 0.0

        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model_exp1(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        exp1_losses.append(avg_loss)

        acc, _, _ = evaluate(model_exp1, test_loader)  #fixed
        exp1_accs.append(acc)

        mlflow.log_metric("loss", avg_loss, step=epoch)
        mlflow.log_metric("accuracy", acc, step=epoch)

        print(f"Epoch {epoch+1}: Loss={avg_loss:.4f}, Acc={acc:.4f}")

    mlflow.log_metric("final_accuracy", float(exp1_accs[-1]))
    mlflow.pytorch.log_model(model_exp1, "cnn_more_filters")

# Eval test set, compare to baseline CNN
exp1_test_acc, _, _ = evaluate(model_exp1, test_loader)

print(f"Experiment 1 (More Filters) Accuracy: {exp1_test_acc:.4f}")
print(f"Baseline CNN Accuracy: {cnn_test_acc:.4f}")

if exp1_test_acc > cnn_test_acc:
    print("Experiment 1 improved performance")
else:
    print("Experiment 1 did NOT improve performance")
# Out:
# Epoch 1: Loss=0.1293, Acc=0.9809
# Epoch 2: Loss=0.0421, Acc=0.9887
# Epoch 3: Loss=0.0278, Acc=0.9877
# Epoch 4: Loss=0.0210, Acc=0.9898
# 2026/03/21 16:05:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/21 16:05:48 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 5: Loss=0.0163, Acc=0.9926
# Experiment 1 (More Filters) Accuracy: 0.9926
# Baseline CNN Accuracy: 0.9899
# Experiment 1 improved performance

# %%
# Experiment 2 - larger kernel
class CNN_LargeKernel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, padding=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, padding=2)
        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# train CNN, log to MLflow
model_exp2 = CNN_LargeKernel()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_exp2.parameters(), lr=0.001)

with mlflow.start_run():
    mlflow.log_param("model", "CNN_LargeKernel")
    mlflow.log_param("lr", 0.001)
    mlflow.log_param("epochs", 5)

    exp2_losses = []
    exp2_accs = []

    for epoch in range(5):
        model_exp2.train()
        running_loss = 0.0

        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model_exp2(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        exp2_losses.append(avg_loss)

        acc, _, _ = evaluate(model_exp2, test_loader)  #fixed
        exp2_accs.append(acc)

        mlflow.log_metric("loss", avg_loss, step=epoch)
        mlflow.log_metric("accuracy", acc, step=epoch)

        print(f"Epoch {epoch+1}: Loss={avg_loss:.4f}, Acc={acc:.4f}")

    mlflow.log_metric("final_accuracy", float(exp2_accs[-1]))
    mlflow.pytorch.log_model(model_exp2, "cnn_large_kernel")

#evaulate test set, compare to baseline CNN
exp2_test_acc, _, _ = evaluate(model_exp2, test_loader)

print(f"Experiment 2 (Large Kernel) Accuracy: {exp2_test_acc:.4f}")
print(f"Baseline CNN Accuracy: {cnn_test_acc:.4f}")

if exp2_test_acc > cnn_test_acc:
    print("Experiment 2 improved performance")
else:
    print("Experiment 2 did NOT improve performance")
# Out:
# Epoch 1: Loss=0.1435, Acc=0.9876
# Epoch 2: Loss=0.0446, Acc=0.9855
# Epoch 3: Loss=0.0306, Acc=0.9904
# Epoch 4: Loss=0.0230, Acc=0.9900
# 2026/03/21 16:07:53 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/21 16:07:53 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 5: Loss=0.0175, Acc=0.9921
# Experiment 2 (Large Kernel) Accuracy: 0.9921
# Baseline CNN Accuracy: 0.9899
# Experiment 2 improved performance

# %% [markdown]
# ## Part 5: Open Exploration
#
# Try at least **one** additional modification beyond Part 4. Some ideas:
#
# - Add dropout (`nn.Dropout` or `nn.Dropout2d`).
# - Add batch normalization (`nn.BatchNorm2d`).
# - Add a third convolutional block.
# - Try a different optimizer (e.g., SGD with momentum vs. Adam).
# - Experiment with learning rate schedules.
# - Add data augmentation (random rotations, slight shifts) via `transforms`.
# - Try a much deeper or much shallower architecture.
#
# Log each experiment to MLflow. In your writeup, explain what you tried, what you expected to happen, and what actually happened.

# %%
# Open exploration experiment(s) - dropout
class CNN_Dropout(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)

# train CNN and log to MLflow
model_exp3 = CNN_Dropout()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_exp3.parameters(), lr=0.001)

with mlflow.start_run():
    mlflow.log_param("model", "CNN_Dropout")
    mlflow.log_param("lr", 0.001)
    mlflow.log_param("epochs", 5)

    exp3_losses = []
    exp3_accs = []

    for epoch in range(5):
        model_exp3.train()
        running_loss = 0.0

        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model_exp3(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        exp3_losses.append(avg_loss)

        acc, _, _ = evaluate(model_exp3, test_loader)  #fixed
        exp3_accs.append(acc)

        mlflow.log_metric("loss", avg_loss, step=epoch)
        mlflow.log_metric("accuracy", acc, step=epoch)

        print(f"Epoch {epoch+1}: Loss={avg_loss:.4f}, Acc={acc:.4f}")

    mlflow.log_metric("final_accuracy", float(exp3_accs[-1]))
    mlflow.pytorch.log_model(model_exp3, "cnn_dropout")

#evaluate on test set, compare to baseline CNN
exp3_test_acc, _, _ = evaluate(model_exp3, test_loader)

print(f"Experiment 3 (Dropout) Accuracy: {exp3_test_acc:.4f}")
print(f"Baseline CNN Accuracy: {cnn_test_acc:.4f}")

if exp3_test_acc > cnn_test_acc:
    print("Dropout improved performance")
else:
    print("Dropout did NOT improve performance")
# Out:
# Epoch 1: Loss=0.2342, Acc=0.9816
# Epoch 2: Loss=0.0911, Acc=0.9872
# Epoch 3: Loss=0.0713, Acc=0.9876
# Epoch 4: Loss=0.0586, Acc=0.9890
# 2026/03/21 16:10:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/21 16:10:10 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 5: Loss=0.0488, Acc=0.9890
# Experiment 3 (Dropout) Accuracy: 0.9890
# Baseline CNN Accuracy: 0.9899
# Dropout did NOT improve performance

# %% [markdown]
# ## Part 6: MLflow Logging
#
# Every training run (MLP baseline, base CNN, each experiment) must be logged to MLflow. For each run, log:
#
# - **Parameters:** learning rate, batch size, number of epochs, optimizer name.
# - **Tag:** a short architecture description (e.g., `"SimpleCNN"`, `"MLP-baseline"`, `"CNN-5x5kernels"`).
# - **Metrics:** training loss per epoch, test accuracy at the end of training.
# - **Artifact:** a confusion matrix saved as a `.png` file.
#
# For the confusion matrix, use `sklearn.metrics.confusion_matrix` and `ConfusionMatrixDisplay`. Save the figure with `plt.savefig()` and log it with `mlflow.log_artifact()`. Refer to your earlier labs for the MLflow logging pattern.
#
# If you haven't already been logging as you go in Parts 2–5, go back and add MLflow logging to each run now. It's much easier to log as you train than to reconstruct runs after the fact.

# %%
# !mlflow ui
# Out:
# Backend store URI not provided. Using sqlite:///mlflow.db
# Registry store URI not provided. Using backend store URI.
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:43 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/03/21 16:19:43 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/21 16:19:43 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# INFO:     Started parent process [12051]
# 2026/03/21 16:19:44 INFO mlflow.server.jobs.utils: Starting huey consumer for job function run_online_trace_scorer
# 2026/03/21 16:19:44 INFO mlflow.server.jobs.utils: Starting huey consumer for job function run_online_session_scorer
# 2026/03/21 16:19:44 INFO mlflow.server.jobs.utils: Starting huey consumer for job function invoke_scorer
# 2026/03/21 16:19:45 INFO mlflow.server.jobs.utils: Starting dedicated Huey consumer for periodic tasks
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:45 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# INFO:     Started server process [12056]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12054]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12055]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12057]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# 2026/03/21 16:19:45 INFO mlflow.server.jobs.utils: Registered online_scoring_scheduler periodic task (runs every 1 minute)
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Huey consumer started with 5 thread, PID 12068 at 2026-03-21 23:19:45.955400
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Huey consumer started with 5 thread, PID 12071 at 2026-03-21 23:19:45.955513
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Scheduler runs every 1 second(s).
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Periodic tasks are enabled.
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:The following commands are available:
# + mlflow.server.jobs.utils._exec_job
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Scheduler runs every 1 second(s).
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:Periodic tasks are enabled.
# [2026-03-21 16:19:45,955] INFO:huey.consumer:MainThread:The following commands are available:
# + mlflow.server.jobs.utils._exec_job
# + mlflow.server.jobs.utils.online_scoring_scheduler
# [2026-03-21 16:19:45,956] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 673c86bd-b6de-4d9e-99ce-6455e442988d.
# [2026-03-21 16:19:45,958] INFO:huey:Worker-4:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 673c86bd-b6de-4d9e-99ce-6455e442988d
# [2026-03-21 16:19:45,960] INFO:huey.consumer:MainThread:Huey consumer started with 5 thread, PID 12070 at 2026-03-21 23:19:45.960535
# [2026-03-21 16:19:45,960] INFO:huey.consumer:MainThread:Scheduler runs every 1 second(s).
# [2026-03-21 16:19:45,960] INFO:huey.consumer:MainThread:Periodic tasks are enabled.
# [2026-03-21 16:19:45,960] INFO:huey.consumer:MainThread:The following commands are available:
# + mlflow.server.jobs.utils._exec_job
# [2026-03-21 16:19:45,961] INFO:huey.consumer:MainThread:Huey consumer started with 10 thread, PID 12069 at 2026-03-21 23:19:45.961432
# [2026-03-21 16:19:45,961] INFO:huey.consumer:MainThread:Scheduler runs every 1 second(s).
# [2026-03-21 16:19:45,961] INFO:huey.consumer:MainThread:Periodic tasks are enabled.
# [2026-03-21 16:19:45,961] INFO:huey.consumer:MainThread:The following commands are available:
# + mlflow.server.jobs.utils._exec_job
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:46 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# [2026-03-21 16:19:46,148] INFO:huey:Worker-4:mlflow.server.jobs.utils.online_scoring_scheduler: 673c86bd-b6de-4d9e-99ce-6455e442988d executed in 0.191s
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/03/21 16:19:55 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# INFO:     127.0.0.1:59320 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59320 - "GET /ajax-api/3.0/mlflow/assistant/config HTTP/1.1" 200 OK
# 2026/03/21 16:20:33 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/21 16:20:33 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# INFO:     127.0.0.1:59320 - "GET /ajax-api/2.0/mlflow/experiments/search?max_results=5&order_by=last_update_time+DESC HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59321 - "GET /ajax-api/3.0/mlflow/ui-telemetry HTTP/1.1" 200 OK
# 2026/03/21 16:20:39 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/21 16:20:39 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# INFO:     127.0.0.1:59323 - "GET /server-info HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59324 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59323 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59324 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59323 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59324 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59323 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# 2026/03/21 16:20:40 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/21 16:20:40 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# INFO:     127.0.0.1:59325 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# [2026-03-21 16:20:45,958] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 744d4a03-bd4b-4e14-a43c-cff84efba01e.
# [2026-03-21 16:20:52,547] INFO:huey:Worker-1:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 744d4a03-bd4b-4e14-a43c-cff84efba01e
# [2026-03-21 16:20:52,548] INFO:huey:Worker-1:mlflow.server.jobs.utils.online_scoring_scheduler: 744d4a03-bd4b-4e14-a43c-cff84efba01e executed in 0.002s
# INFO:     127.0.0.1:59326 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59339 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# [2026-03-21 16:21:45,958] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 657f3e1d-c4c4-4ca6-9633-b42a12c04568.
# [2026-03-21 16:21:50,374] INFO:huey:Worker-1:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 657f3e1d-c4c4-4ca6-9633-b42a12c04568
# [2026-03-21 16:21:50,378] INFO:huey:Worker-1:mlflow.server.jobs.utils.online_scoring_scheduler: 657f3e1d-c4c4-4ca6-9633-b42a12c04568 executed in 0.004s
# INFO:     127.0.0.1:59341 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59343 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%272d21bebfce4c4b6d8f83397f678da6c8%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59342 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59343 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59342 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%252d21bebfce4c4b6d8f83397f678da6c8%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59345 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59346 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59346 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59345 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59346 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%271bb6763f24d74d0693ab5d962fcc09d0%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59344 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59346 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%251bb6763f24d74d0693ab5d962fcc09d0%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59345 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# [2026-03-21 16:22:45,957] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 6165f579-69ea-4172-96b6-1f62efc47029.
# [2026-03-21 16:22:48,211] INFO:huey:Worker-1:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 6165f579-69ea-4172-96b6-1f62efc47029
# [2026-03-21 16:22:48,213] INFO:huey:Worker-1:mlflow.server.jobs.utils.online_scoring_scheduler: 6165f579-69ea-4172-96b6-1f62efc47029 executed in 0.001s
# INFO:     127.0.0.1:59347 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%251bb6763f24d74d0693ab5d962fcc09d0%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59349 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%251bb6763f24d74d0693ab5d962fcc09d0%25%22 HTTP/1.1" 200 OK
# [2026-03-21 16:23:45,961] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: c41561dc-0a0b-442a-8fe9-630c928d6a0e.
# [2026-03-21 16:23:46,043] INFO:huey:Worker-1:Executing mlflow.server.jobs.utils.online_scoring_scheduler: c41561dc-0a0b-442a-8fe9-630c928d6a0e
# [2026-03-21 16:23:46,049] INFO:huey:Worker-1:mlflow.server.jobs.utils.online_scoring_scheduler: c41561dc-0a0b-442a-8fe9-630c928d6a0e executed in 0.006s
# INFO:     127.0.0.1:59350 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%251bb6763f24d74d0693ab5d962fcc09d0%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59350 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59351 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59352 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59350 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59352 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59351 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59352 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%273f8bc122a25047c1ba96ef75f92bc7bf%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59350 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59352 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%253f8bc122a25047c1ba96ef75f92bc7bf%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59351 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59350 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59353 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%253f8bc122a25047c1ba96ef75f92bc7bf%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59353 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59354 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59355 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59353 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59354 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59355 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59356 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59358 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%27aaf6d03fbd5f4f0fb61809f2b1b830bd%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59357 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59357 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25aaf6d03fbd5f4f0fb61809f2b1b830bd%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59358 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59359 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# [2026-03-21 16:24:45,961] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: b990bf31-72b3-43e6-ac80-971f48f41e51.
# INFO:     127.0.0.1:59360 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59361 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59362 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59360 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59361 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59362 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# [2026-03-21 16:24:52,627] INFO:huey:Worker-5:Executing mlflow.server.jobs.utils.online_scoring_scheduler: b990bf31-72b3-43e6-ac80-971f48f41e51
# [2026-03-21 16:24:52,632] INFO:huey:Worker-5:mlflow.server.jobs.utils.online_scoring_scheduler: b990bf31-72b3-43e6-ac80-971f48f41e51 executed in 0.004s
# INFO:     127.0.0.1:59361 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%276a272823678b466b9c75f88684bcd791%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59360 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59361 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59360 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59362 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59363 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59363 - "GET /static-files/static/js/5839.e1f179e1.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59363 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=6a272823678b466b9c75f88684bcd791&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59364 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=6a272823678b466b9c75f88684bcd791&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59364 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59363 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59366 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=6a272823678b466b9c75f88684bcd791&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59366 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=6a272823678b466b9c75f88684bcd791&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# [2026-03-21 16:25:45,961] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 7b188b35-eba7-4458-a906-577b19997f87.
# [2026-03-21 16:25:50,472] INFO:huey:Worker-5:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 7b188b35-eba7-4458-a906-577b19997f87
# [2026-03-21 16:25:50,476] INFO:huey:Worker-5:mlflow.server.jobs.utils.online_scoring_scheduler: 7b188b35-eba7-4458-a906-577b19997f87 executed in 0.004s
# INFO:     127.0.0.1:59368 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59367 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59369 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# [2026-03-21 16:26:45,960] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: cbcdba15-37a5-4164-897c-8cb2dea7c5c0.
# [2026-03-21 16:26:48,300] INFO:huey:Worker-5:Executing mlflow.server.jobs.utils.online_scoring_scheduler: cbcdba15-37a5-4164-897c-8cb2dea7c5c0
# [2026-03-21 16:26:48,304] INFO:huey:Worker-5:mlflow.server.jobs.utils.online_scoring_scheduler: cbcdba15-37a5-4164-897c-8cb2dea7c5c0 executed in 0.003s
# INFO:     127.0.0.1:59412 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%256a272823678b466b9c75f88684bcd791%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59415 - "GET /static-files/static/js/7056.113879be.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59414 - "GET /static-files/static/css/7056.72f0cec1.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59415 - "GET /ajax-api/2.0/mlflow/logged-models/m-b23165f6b8684e69a71dd08c77f6321e HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59414 - "GET /ajax-api/2.0/mlflow/registered-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59415 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=6a272823678b466b9c75f88684bcd791 HTTP/1.1" 200 OK
# [2026-03-21 16:27:45,960] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: 992a2e33-cdbf-4063-a117-3766c9e79c13.
# [2026-03-21 16:27:46,137] INFO:huey:Worker-5:Executing mlflow.server.jobs.utils.online_scoring_scheduler: 992a2e33-cdbf-4063-a117-3766c9e79c13
# [2026-03-21 16:27:46,143] INFO:huey:Worker-5:mlflow.server.jobs.utils.online_scoring_scheduler: 992a2e33-cdbf-4063-a117-3766c9e79c13 executed in 0.005s
# INFO:     127.0.0.1:59416 - "GET /static-files/static/css/6036.f482616c.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59417 - "GET /static-files/static/js/6036.8c946d12.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59418 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59416 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# 2026/03/21 16:28:07 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/03/21 16:28:07 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# INFO:     127.0.0.1:59419 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59417 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1bb6763f24d74d0693ab5d962fcc09d0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59418 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3f8bc122a25047c1ba96ef75f92bc7bf HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59416 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=aaf6d03fbd5f4f0fb61809f2b1b830bd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59420 - "GET / HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59420 - "GET /ajax-api/3.0/mlflow/assistant/config HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59421 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%271bb6763f24d74d0693ab5d962fcc09d0%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59420 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59420 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%251bb6763f24d74d0693ab5d962fcc09d0%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59422 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59421 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59420 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59422 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# [2026-03-21 16:28:45,958] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: c65fd803-228c-447c-865b-c2fd23ee158a.
# INFO:     127.0.0.1:59424 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59424 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# [2026-03-21 16:28:52,713] INFO:huey:Worker-3:Executing mlflow.server.jobs.utils.online_scoring_scheduler: c65fd803-228c-447c-865b-c2fd23ee158a
# [2026-03-21 16:28:52,719] INFO:huey:Worker-3:mlflow.server.jobs.utils.online_scoring_scheduler: c65fd803-228c-447c-865b-c2fd23ee158a executed in 0.005s
# INFO:     127.0.0.1:59425 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59425 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# [2026-03-21 16:29:45,960] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: e261e6ee-b91a-422c-a5e3-c4738bb09dd7.
# INFO:     127.0.0.1:59429 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59429 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# [2026-03-21 16:29:50,550] INFO:huey:Worker-3:Executing mlflow.server.jobs.utils.online_scoring_scheduler: e261e6ee-b91a-422c-a5e3-c4738bb09dd7
# [2026-03-21 16:29:50,555] INFO:huey:Worker-3:mlflow.server.jobs.utils.online_scoring_scheduler: e261e6ee-b91a-422c-a5e3-c4738bb09dd7 executed in 0.004s
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/artifacts/list?run_uuid=1bb6763f24d74d0693ab5d962fcc09d0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/directories HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59430 - "GET /static-files/static/media/fontawesome-webfont.20fd1704ea223900efa9.woff2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/directories?artifact_directory_path=data HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%271bb6763f24d74d0693ab5d962fcc09d0%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=data%2Fpickle_module_info.txt HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=MLmodel HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=conda.yaml HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=python_env.yaml HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=requirements.txt HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=python_env.yaml HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=conda.yaml HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=requirements.txt HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=MLmodel HTTP/1.1" 304 Not Modified
# [2026-03-21 16:30:45,960] INFO:huey.consumer.Scheduler:Scheduler:Enqueueing periodic task mlflow.server.jobs.utils.online_scoring_scheduler: c9a66ba8-d43e-41b2-9558-5c71a4bd3c36.
# [2026-03-21 16:30:48,375] INFO:huey:Worker-3:Executing mlflow.server.jobs.utils.online_scoring_scheduler: c9a66ba8-d43e-41b2-9558-5c71a4bd3c36
# [2026-03-21 16:30:48,381] INFO:huey:Worker-3:mlflow.server.jobs.utils.online_scoring_scheduler: c9a66ba8-d43e-41b2-9558-5c71a4bd3c36 executed in 0.006s
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/logged-models/m-42cd7d1416334a1ebd5ce4ea57abe9a0/artifacts/files?artifact_file_path=MLmodel HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59432 - "POST /ajax-api/3.0/mlflow/traces/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "POST /ajax-api/3.0/mlflow/traces/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "POST /ajax-api/3.0/mlflow/datasets/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59432 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59431 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=accuracy&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59432 - "GET /ajax-api/2.0/mlflow/metrics/get-history-bulk-interval?run_ids=1bb6763f24d74d0693ab5d962fcc09d0&metric_key=loss&max_results=320 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59433 - "GET /server-info HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59434 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59434 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59433 - "GET /ajax-api/2.0/mlflow/experiments/get?experiment_id=2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59436 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=2&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59437 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59435 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59434 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59433 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59438 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59438 - "POST /ajax-api/3.0/mlflow/ui-telemetry HTTP/1.1" 200 OK
# ^C[2026-03-21 16:31:44,296] INFO:huey.consumer:MainThread:Shutting down gracefully...
#
# [2026-03-21 16:31:44,308] INFO:huey.consumer:MainThread:Received request to shut down now.
# [2026-03-21 16:31:44,308] INFO:huey.consumer:MainThread:Consumer exiting.
# [2026-03-21 16:31:44,308] INFO:huey.consumer:MainThread:Received SIGINT
# [2026-03-21 16:31:44,308] INFO:huey.consumer:MainThread:Shutting down gracefully...
#
# Aborted!
# INFO:     Shutting down
# Traceback (most recent call last):
# INFO:     Shutting down
# Traceback (most recent call last):
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/bin/huey_consumer.py", line 68, in <module>
#     consumer_main()
#     ~~~~~~~~~~~~~^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/bin/huey_consumer.py", line 56, in consumer_main
#     consumer.run()
#     ~~~~~~~~~~~~^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 442, in run
#     health_check_ts = self.loop(health_check_ts)
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 466, in loop
#     self.stop(graceful=self._graceful)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 420, in stop
#     self._logger.info('Shutting down gracefully...')
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1520, in info
#     self._log(INFO, msg, args, **kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1665, in _log
#     self.handle(record)
#     ~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1681, in handle
#     self.callHandlers(record)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1737, in callHandlers
#     hdlr.handle(record)
#     ~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/bin/huey_consumer.py", line 68, in <module>
#     consumer_main()
#     ~~~~~~~~~~~~~^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1027, in handle
#     self.emit(record)
#     ~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1154, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/bin/huey_consumer.py", line 56, in consumer_main
#     consumer.run()
#     ~~~~~~~~~~~~^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 442, in run
#     health_check_ts = self.loop(health_check_ts)
# KeyboardInterrupt
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 466, in loop
#     self.stop(graceful=self._graceful)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/site-packages/huey/consumer.py", line 420, in stop
#     self._logger.info('Shutting down gracefully...')
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1520, in info
#     self._log(INFO, msg, args, **kwargs)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1665, in _log
#     self.handle(record)
#     ~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1681, in handle
#     self.callHandlers(record)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1737, in callHandlers
#     hdlr.handle(record)
#     ~~~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1027, in handle
#     self.emit(record)
#     ~~~~~~~~~^^^^^^^^
#   File "/Users/hughbaldwin/miniconda3/envs/dl-lab/lib/python3.14/logging/__init__.py", line 1154, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Finished server process [12056]
# INFO:     Finished server process [12054]
# INFO:     Finished server process [12055]
# INFO:     Waiting for child process [12055]
# INFO:     Finished server process [12057]
# INFO:     Waiting for child process [12056]
# INFO:     Waiting for child process [12057]
# INFO:     Stopping parent process [12051]

# %% [markdown]
# ## Part 7: Visualization
#
# After training your best CNN, visualize what it has learned. Work through the **CNN Visualization Tutorial** notebook (`cnn_visualization_tutorial.ipynb`) first — it walks through every technique on a FashionMNIST model with full working code. Then come back here and adapt the code to your MNIST model.
#
# You need to produce two visualizations:
#
# 1. **Learned conv1 filters** — display the first layer's weights as a grid of small grayscale images.
# 2. **Intermediate feature maps** — pass a single MNIST digit through your model layer by layer and display the feature maps after each conv layer.
#
# The tutorial notebook has all the code you need; the only changes are your model variable name and layer names.

# %%
# Visualize learned conv1 filters
# (Adapt from Part 1 of the visualization tutorial)
import matplotlib.pyplot as plt

def visualize_conv1_filters(model):
    weights = model.conv1.weight.data  # shape: (num_filters, 1, k, k)

    num_filters = weights.shape[0]

    fig, axes = plt.subplots(1, min(num_filters, 8), figsize=(12, 3))

    for i in range(min(num_filters, 8)):
        ax = axes[i]
        ax.imshow(weights[i, 0].cpu(), cmap='gray')
        ax.set_title(f"Filter {i}")
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# call it
visualize_conv1_filters(model)

# %%
# Visualize intermediate feature maps on a sample MNIST digit
# (Adapt from Part 2 of the visualization tutorial)
def visualize_feature_maps(model, image):
    model.eval()

    with torch.no_grad():
        x = image.unsqueeze(0)  # add batch dimension
        x = model.conv1(x)
        x = F.relu(x)

    num_maps = x.shape[1]

    fig, axes = plt.subplots(1, min(num_maps, 8), figsize=(12, 3))

    for i in range(min(num_maps, 8)):
        ax = axes[i]
        ax.imshow(x[0, i].cpu(), cmap='gray')
        ax.set_title(f"Map {i}")
        ax.axis('off')

    plt.tight_layout()
    plt.show()

#feature map visualization
# get a sample image
images, labels = next(iter(test_loader))

sample_img = images[0]

visualize_feature_maps(model, sample_img)

# %% [markdown]
# ---
#
# ## Deliverables
#
# Submit two files:
#
# ### 1. This notebook (`.ipynb`)
#
# Your complete, executed notebook containing all code, outputs, and results for Parts 1–7. The notebook should run top to bottom without errors.
#
# ### 2. Writeup (`.md` or `.pdf`)
#
# A short report (1–2 pages) covering:
#
# - **Baseline comparison:** MLP vs. base CNN — what was the accuracy difference? Why does the CNN do better (or not)?
# - **Experiment summary:** A table of all your MLflow runs showing architecture, key hyperparameters, and test accuracy.
# - **Analysis of experiments:** For each experiment in Parts 4 and 5, what did you change, what did you expect, and what happened? Reference your MLflow metrics.
# - **Visualization discussion:** What do the learned filters look like? How do the feature maps relate to the input?
# - **Reflection:** What surprised you? If you had another week, what would you try next?
#
# ---

# %% [markdown]
# ## Grading Rubric
#
# | Component | Points |
# |-----------|--------|
# | CNN classifier (working, logged) | 20 |
# | Kernel size / filter count experiments (at least two, logged) | 20 |
# | Open exploration (at least one, logged) | 20 |
# | MLflow logging (all runs, parameters, tags, confusion matrices) | 20 |
# | Visualization (learned filters + intermediate feature maps) | 20 |
# | Writeup (comparison, analysis, reflection) | 50 |
# | **Total** | **150** |
#
# ---

# %% [markdown]
# ## Tips
#
# - **Start with Part 2.** If your MLP training loop works, everything else is a model swap.
# - **Reuse code.** Write a `train_and_evaluate` function that takes a model, trains it, evaluates it, and logs everything to MLflow. Then call it for each experiment. You'll thank yourself.
# - **Track your shapes.** Most CNN bugs are shape mismatches. Print `x.shape` after each layer, or use the shape-tracing technique from Day 2.
# - **Don't overtrain.** MNIST is a small dataset. If your model isn't converging in 5–10 epochs, something is wrong with the setup, not the number of epochs.
# - **Name your MLflow runs.** Future-you will thank present-you when comparing 8 runs in the MLflow UI.
